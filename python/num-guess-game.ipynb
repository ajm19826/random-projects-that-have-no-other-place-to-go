# %% [markdown]
# # Number Guessing Game

# %%
# import statements
import random

# %%
# stores random number
print('Random Number Guessing Game')
rawrange = input('Please input number range. etc: "1 - 10"')
out = rawrange.split(' - ')
# Out:
# Random Number Guessing Game
# Please input number range. etc: "1 - 10" 5 - 8
