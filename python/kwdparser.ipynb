# %% [markdown]
# # Keyword parser

# %%
myString = input('Enter sentence:')
def cleanWord(word):
    return word.replace('.', '').lower()

[cleanWord(word) for word in myString.split()]
# Out:
# Enter sentence: There is a quick brown fox. It jumps over the lazy dog
# ['there',
#  'is',
#  'a',
#  'quick',
#  'brown',
#  'fox',
#  'it',
#  'jumps',
#  'over',
#  'the',
#  'lazy',
#  'dog']

# %%
# Sentence splitter
myString = input('Enter sentence:')

def cleanWord(word):
    return word.replace('.', '').lower()

[[cleanWord(word) for word in sentence.split()] for sentence in myString.split('.')]
# Out:
# Enter sentence: There is a quick brown fox. It jumps over the lazy dog
# [['there', 'is', 'a', 'quick', 'brown', 'fox'],
#  ['it', 'jumps', 'over', 'the', 'lazy', 'dog']]

# %%
# less then 3 only
myString = input('Enter sentence:')

def cleanWord(word):
    return word.replace('.', '').lower()
[cleanWord(word) for word in myString.split() if len(cleanWord(word)) < 3]
# Out:
# Enter sentence: There is a quick brown fox. It jumps over the lazy dog
# ['is', 'a', 'it']
